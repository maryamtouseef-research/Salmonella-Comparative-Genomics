# %%
from collections import Counter

file_path = "/content/GCA_000006945.2_ASM694v2_genomic.fna"

with open(file_path, "r") as f:
    sequence = "".join(
        line.strip() for line in f
        if not line.startswith(">")
    )

counts = Counter(sequence.upper())

length = len(sequence)
gc_count = counts["G"] + counts["C"]
gc_percent = (gc_count / length) * 100

print("Genome:", "GCA_000006945.2")
print("Genome length:", length, "bp")
print("A:", counts["A"])
print("T:", counts["T"])
print("G:", counts["G"])
print("C:", counts["C"])
print("GC content:", round(gc_percent, 2), "%")
# Out:
# Genome: GCA_000006945.2
# Genome length: 4951383 bp
# A: 1183215
# T: 1181621
# G: 1294057
# C: 1292490
# GC content: 52.24 %

# %%
from collections import Counter

file_path = "/content/GCA_000252995.1_ASM25299v1_genomic.fna"

with open(file_path, "r") as f:
    sequence = "".join(
        line.strip()
        for line in f
        if not line.startswith(">")
    )

counts = Counter(sequence.upper())

length = len(sequence)
gc_count = counts["G"] + counts["C"]
gc_percent = (gc_count / length) * 100

print("Genome: GCA_000252995.1")
print("Organism: Salmonella bongori")
print("Strain: NCTC 12419")
print("Genome length:", length, "bp")
print("A:", counts["A"])
print("T:", counts["T"])
print("G:", counts["G"])
print("C:", counts["C"])
print("GC content:", round(gc_percent, 2), "%")
# Out:
# Genome: GCA_000252995.1
# Organism: Salmonella bongori
# Strain: NCTC 12419
# Genome length: 4460105 bp
# A: 1085539
# T: 1085208
# G: 1143870
# C: 1145488
# GC content: 51.33 %

# %%
from collections import Counter
import glob

files = glob.glob("/content/GCA_006365335.1*.fna")

print("Files found:", files)

if len(files) == 0:
    print("ERROR: The GCA_006365335.1 FASTA file is not uploaded to Colab.")
else:
    file_path = files[0]

    with open(file_path, "r") as f:
        sequence = "".join(
            line.strip()
            for line in f
            if not line.startswith(">")
        )

    counts = Counter(sequence.upper())

    length = len(sequence)
    gc_count = counts["G"] + counts["C"]
    gc_percent = (gc_count / length) * 100

    print("Genome: GCA_006365335.1")
    print("Organism: Salmonella enterica")
    print("Strain: FDAARGOS_768")
    print("Genome length:", length, "bp")
    print("A:", counts["A"])
    print("T:", counts["T"])
    print("G:", counts["G"])
    print("C:", counts["C"])
    print("GC content:", round(gc_percent, 2), "%")
# Out:
# Files found: ['/content/GCA_006365335.1_ASM636533v1_genomic.fna']
# Genome: GCA_006365335.1
# Organism: Salmonella enterica
# Strain: FDAARGOS_768
# Genome length: 4954783 bp
# A: 1182970
# T: 1184314
# G: 1293040
# C: 1294459
# GC content: 52.22 %

# %%
from collections import Counter

file_path = "/content/GCA_022869965.1_ASM2286996v1_genomic.fna"

with open(file_path, "r") as f:
    sequence = "".join(
        line.strip()
        for line in f
        if not line.startswith(">")
    )

counts = Counter(sequence.upper())

length = len(sequence)
gc_count = counts["G"] + counts["C"]
gc_percent = (gc_count / length) * 100

print("Genome: GCA_022869965.1")
print("Genome length:", length, "bp")
print("A:", counts["A"])
print("T:", counts["T"])
print("G:", counts["G"])
print("C:", counts["C"])
print("GC content:", round(gc_percent, 2), "%")
# Out:
# Genome: GCA_022869965.1
# Genome length: 4951425 bp
# A: 1182630
# T: 1182221
# G: 1292303
# C: 1294271
# GC content: 52.24 %

# %%
from collections import Counter

file_path = "/content/GCA_022869965.1_ASM2286996v1_genomic.fna"

with open(file_path, "r") as f:
    sequence = "".join(
        line.strip()
        for line in f
        if not line.startswith(">")
    )

counts = Counter(sequence.upper())

length = len(sequence)
gc_count = counts["G"] + counts["C"]
gc_percent = (gc_count / length) * 100

print("Genome: GCA_022869965.1")
print("Genome length:", length, "bp")
print("A:", counts["A"])
print("T:", counts["T"])
print("G:", counts["G"])
print("C:", counts["C"])
print("GC content:", round(gc_percent, 2), "%")
# Out:
# Genome: GCA_022869965.1
# Genome length: 4951425 bp
# A: 1182630
# T: 1182221
# G: 1292303
# C: 1294271
# GC content: 52.24 %

# %%
import matplotlib.pyplot as plt
plt.savefig("gc_content_comparison.png", dpi=300, bbox_inches="tight")

genomes = [
    "GCA_000006945.2",
    "GCA_000252995.1",
    "GCA_006365335.1",
    "GCA_022869965.1"
]

gc_content = [
    52.24,
    51.33,
    52.22,
    52.24
]

plt.bar(genomes, gc_content)

plt.xlabel("Genome")
plt.ylabel("GC Content (%)")
plt.title("GC Content Comparison")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

genomes = [
    "GCA_000006945.2",
    "GCA_000252995.1",
    "GCA_006365335.1",
    "GCA_022869965.1"
]

gc_content = [
    52.24,
    51.33,
    52.22,
    52.24
]

plt.bar(genomes, gc_content)

plt.xlabel("Genome")
plt.ylabel("GC Content (%)")
plt.title("GC Content Comparison")

plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("gc_content_comparison.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import pandas as pd
df.to_csv("genome_results.csv", index=False)

results = {
    "Genome": [
        "GCA_000006945.2",
        "GCA_000252995.1",
        "GCA_006365335.1",
        "GCA_022869965.1"
    ],

    "Genome_Length_bp": [
        4951383,
        4460105,
        4954783,
        4951425
    ],

    "GC_Content_percent": [
        52.24,
        51.33,
        52.22,
        52.24
    ]
}

df = pd.DataFrame(results)

df
# Out:
#             Genome  Genome_Length_bp  GC_Content_percent
# 0  GCA_000006945.2           4951383               52.24
# 1  GCA_000252995.1           4460105               51.33
# 2  GCA_006365335.1           4954783               52.22
# 3  GCA_022869965.1           4951425               52.24

# %%
import matplotlib.pyplot as plt

genomes = [
    "GCA_000006945.2",
    "GCA_000252995.1",
    "GCA_006365335.1",
    "GCA_022869965.1"
]

genome_length = [
    4951383,
    4460105,
    4954783,
    4951425
]

plt.bar(genomes, genome_length)

plt.xlabel("Genome")
plt.ylabel("Genome Length (bp)")
plt.title("Genome Size Comparison")

plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("genome_size_comparison.png", dpi=300, bbox_inches="tight")

plt.show()
